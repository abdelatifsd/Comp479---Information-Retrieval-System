# %%
#!pip install boilerpipe3

# %% [markdown]
# # This program was used to generate documents from pure URL links

# %%
import csv
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import re,os
import nltk
import pickle 
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer 
ps = PorterStemmer()
import numpy as np
from operator import itemgetter
from boilerpipe.extract import Extractor
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
links = open('urls_run_final.csv',"r",encoding="utf-8")
#links = schedule_data.values
filtered_links = []

# %%
link = "s"
while link != "":
    link = links.readline().split(";")[0][1:-1]
    if "concordia" in link: 
        filtered_links.append(link)

# %%
len(filtered_links)
# Out:
# 3941296

# %%
filtered_links = list(set(filtered_links))

# %%
len(filtered_links)
# Out:
# 40447

# %%
filtered_links = filtered_links[17589:]

# %%
len(filtered_links)
# Out:
# 22858

# %%
import time

docID_link_map_p2 = {}

count_errors = 0

documents_folder = "" # choose a doc folder

for i,link in enumerate(filtered_links):
    
    try:
        extractor = Extractor(extractor='ArticleExtractor', url=link)
        extracted_text = extractor.getText()
    except:
        print("link:"+str(i)+ " " + link)
        count_errors+=1
        print(count_errors)
        continue
        
    docID_link_map_p2[docID_followup]=link
    
    os.chdir(documents_folder)
    
    text_file = open(str(i+1)+".txt", "w",encoding="utf-8")
    
    text_file.write(extracted_text)
    
    text_file.close()
    
    os.chdir("..")
# Out:
# link:17989 https://www.concordia.ca/encs/electrical-computer/faculty.html?fpid=abdelwahab-hamou-lhadj
# 1
# link:18394 http://www.concordia.ca/alumni-giving/alumni/connect-learn/homecoming/
# 2
# link:18419 https://www.concordia.ca/artsci/geography-planning-environment/faculty.html?fpid=s-robert-aiken
# 3
# link:18554 https://www.concordia.ca/encs/mechanical-industrial/faculty.html?fpid=farjad-shadmehri
# 4
# link:18912 http://www.concordia.ca/artsci/psychology/faculty.html?fpid=mickael-deroche
# 5
# link:19353 https://www.concordia.ca/artsci/journalism/faculty.html?fpid=aaron-derfel
# 6
# link:19429 https://www.concordia.ca/provost/resources/curriculum/ci-fund.html
# 7
# link:19440 https://www.concordia.ca/encs/bcee/facilities-services/research-labs/building-engineering-labs/building-aerodynamics-wind-tunnel-lab.html
# 8
# link:19460 http://www.concordia.ca/content/concordia/fr/recherche/chairejeu/a-propos/equipe/nadeau-fr.html
# 9
# ...
